# %%
import pandas as pd
from models import cities , tests , test_ref
# Out:
# 2025-07-18 02:13:01,996 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-18 02:13:01,998 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("cities")
# 2025-07-18 02:13:01,998 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-18 02:13:02,005 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("tests_refs")
# 2025-07-18 02:13:02,007 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-18 02:13:02,013 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("tests")
# 2025-07-18 02:13:02,015 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-18 02:13:02,017 INFO sqlalchemy.engine.Engine COMMIT

# %%
from sqlalchemy import create_engine 
from sqlalchemy.orm import sessionmaker

# %%
dataframe = pd.read_excel("2016.xlsx" , header=[1,2] ,sheet_name="تعداد" ,skiprows=0  )

# %% [markdown]
# پاکسازی و تصحیح املاهای غلط موجود در نام کالمن های موجود در دیتا فریم

# %%
nl = list(dataframe.columns)

# %%
nl = [('مدیریت برق شهرستان', ''),
 ('کد امور', ''),
 ('سال', ''),
 ('ماه', ''),
 ('تعداد دستورکارهای باز مربوط به تست 1', 'دردست اجرا'),
 ('تعداد دستورکارهای باز مربوط به تست 1', 'تهیه صورت وضعیت'),
 ('تعداد دستورکارهای باز مربوط به تست 1', 'صورت وضعیت نزد ستاد'),
 ('تعداد دستورکارهای باز مربوط به تست 1', 'صورت وضعیت نزد مالی'),
 ('تعداد دستورکارهای باز مربوط به تست 1', 'مجموع دستورکارهای باز بهره برداری'),
 ('تعداد دستورکارهای باز مربوط به تست 2', 'دردست اجرا'),
 ('تعداد دستورکارهای باز مربوط به تست 2', 'تهیه صورت وضعیت'),
 ('تعداد دستورکارهای باز مربوط به تست 2', 'صورت وضعیت نزد ستاد'),
 ('تعداد دستورکارهای باز مربوط به تست 2', 'صورت وضعیت نزد مالی'),
 ('تعداد دستورکارهای باز مربوط به تست 2', 'مجموع دستورکارهای باز لوازم اندازه گیری'),
 ('تعداد دستورکارهای باز مربوط به تست 3', 'دردست اجرا'),
 ('تعداد دستورکارهای باز مربوط به تست 3', 'تهیه صورت وضعیت'),
 ('تعداد دستورکارهای باز مربوط به تست 3', 'صورت وضعیت نزد ستاد'),
 ('تعداد دستورکارهای باز مربوط به تست 3', 'صورت وضعیت نزد مالی'),
 ('تعداد دستورکارهای باز مربوط به تست 3', 'مجموع دستورکارهای باز لوازم اندازه گیری'),
 ('تعداد دستورکارهای باز مربوط به تست 4', 'دردست اجرا'),
 ('تعداد دستورکارهای باز مربوط به تست 4', 'تهیه صورت وضعیت'),
 ('تعداد دستورکارهای باز مربوط به تست 4', 'صورت وضعیت نزد مشاور'),
 ('تعداد دستورکارهای باز مربوط به تست 4', 'صورت وضعیت نزد ستاد'),
 ('تعداد دستورکارهای باز مربوط به تست 4', 'صورت وضعیت نزد مالی'),
 ('تعداد دستورکارهای باز مربوط به تست 4', 'مجموع دستورکارهای باز سیم به کابل'),
 ('تعداد دستورکارهای باز مربوط به تست 5', 'دردست اجرا'),
 ('تعداد دستورکارهای باز مربوط به تست 5', 'تهیه صورت وضعیت'),
 ('تعداد دستورکارهای باز مربوط به تست 5', 'صورت وضعیت نزد مشاور'),
 ('تعداد دستورکارهای باز مربوط به تست 5', 'صورت وضعیت نزد ستاد'),
 ('تعداد دستورکارهای باز مربوط به تست 5', 'صورت وضعیت نزد مالی'),
 ('تعداد دستورکارهای باز مربوط به تست 5', 'مجموع دستورکارهای باز نیرورسانی'),
 ('تعداد دستورکارهای باز مربوط به تست 6', 'دردست اجرا'),
 ('تعداد دستورکارهای باز مربوط به تست 6', 'تهیه صورت وضعیت'),
 ('تعداد دستورکارهای باز مربوط به تست 6', 'صورت وضعیت نزد مشاور'),
 ('تعداد دستورکارهای باز مربوط به تست 6', 'صورت وضعیت نزد ستاد'),
 ('تعداد دستورکارهای باز مربوط به تست 6', 'صورت وضعیت نزد مالی'),
 ('تعداد دستورکارهای باز مربوط به تست 6', 'مجموع دستورکارهای باز تلفات'),
 ('تعداد دستورکارهای باز مربوط به تست 7', 'دردست اجرا'),
 ('تعداد دستورکارهای باز مربوط به تست 7', 'تهیه صورت وضعیت'),
 ('تعداد دستورکارهای باز مربوط به تست 7', 'صورت وضعیت نزد مشاور'),
 ('تعداد دستورکارهای باز مربوط به تست 7', 'صورت وضعیت نزد ستاد'),
 ('تعداد دستورکارهای باز مربوط به تست 7', 'صورت وضعیت نزد مالی'),
 ('تعداد دستورکارهای باز مربوط به تست 7',  'مجموع دستورکارهای باز توسعه و احداث و اصلاح و روشنایی معابر و برگشتی و طرح جامع بم'),
 (' جمع تعداد دستورکارهای باز مربوط به امور', 'دردست اجرا'),
 (' جمع تعداد دستورکارهای باز مربوط به امور', 'تهیه صورت وضعیت'),
 (' جمع تعداد دستورکارهای باز مربوط به امور', 'صورت وضعیت نزد مشاور'),
 (' جمع تعداد دستورکارهای باز مربوط به امور', 'صورت وضعیت نزد ستاد'),
 (' جمع تعداد دستورکارهای باز مربوط به امور', 'صورت وضعیت نزد مالی'),
 (' جمع تعداد دستورکارهای باز مربوط به امور', 'کل دستورکارهای باز')]

# %% [markdown]
# تغییر مولتی ایندکس به مولتی ایندکس جدید اصلاح شده

# %%
dataframe.columns = pd.MultiIndex.from_tuples(nl)

# %% [markdown]
# حذف ردیف های مجموع

# %%
mask = (dataframe[("مدیریت برق شهرستان" , "")] == "کل شرکت" )|( dataframe[("مدیریت برق شهرستان" , "")] == "جمع به تفکیک هر واحد" )
dataframe.drop(index = dataframe[mask].index , axis = 0 , inplace = True)

# %% [markdown]
# حذف ستون های مجموع

# %%
dataframe.drop([
    ('تعداد دستورکارهای باز مربوط به تست 1', 'مجموع دستورکارهای باز بهره برداری'),
    ('تعداد دستورکارهای باز مربوط به تست 2', 'مجموع دستورکارهای باز لوازم اندازه گیری'),
    ('تعداد دستورکارهای باز مربوط به تست 3', 'مجموع دستورکارهای باز لوازم اندازه گیری'),
    ('تعداد دستورکارهای باز مربوط به تست 4', 'مجموع دستورکارهای باز سیم به کابل'),
    ('تعداد دستورکارهای باز مربوط به تست 5', 'مجموع دستورکارهای باز نیرورسانی'),
    ('تعداد دستورکارهای باز مربوط به تست 6', 'مجموع دستورکارهای باز تلفات'),
    ('تعداد دستورکارهای باز مربوط به تست 7',  'مجموع دستورکارهای باز توسعه و احداث و اصلاح و روشنایی معابر و برگشتی و طرح جامع بم'),
 (' جمع تعداد دستورکارهای باز مربوط به امور', 'دردست اجرا'),
 (' جمع تعداد دستورکارهای باز مربوط به امور', 'تهیه صورت وضعیت'),
 (' جمع تعداد دستورکارهای باز مربوط به امور', 'صورت وضعیت نزد مشاور'),
 (' جمع تعداد دستورکارهای باز مربوط به امور', 'صورت وضعیت نزد ستاد'),
 (' جمع تعداد دستورکارهای باز مربوط به امور', 'صورت وضعیت نزد مالی'),
 (' جمع تعداد دستورکارهای باز مربوط به امور', 'کل دستورکارهای باز')] ,axis =1 , inplace = True )

# %% [markdown]
# ذخیره در دیتابیس

# %%
# engine = create_engine("mysql+pymysql://root:1234@localhost/test")
engine = create_engine("sqlite:///database.db")

# %%
Session = sessionmaker(bind = engine)
session = Session()

# %%
session.rollback()

# %%
my_list = [
    ('تعداد دستورکارهای باز مربوط به تست 1', 'مجموع دستورکارهای باز بهره برداری'),
    ('تعداد دستورکارهای باز مربوط به تست 2', 'مجموع دستورکارهای باز لوازم اندازه گیری'),
    ('تعداد دستورکارهای باز مربوط به تست 3', 'مجموع دستورکارهای باز لوازم اندازه گیری')]

# %%
'''
self.test_name = name
        self.test_num = test_num
        self.majmo_name = majmo_name
        self.additional_attrs = additional
        '''
for item in my_list:
    new_t = test_ref(name = item[0] , test_num= item[0][-1:] , majmo_name= item[1] , additional=None)
    session.add(new_t)
session.commit()

# %%
my_list2 = [('تعداد دستورکارهای باز مربوط به تست 4', 'مجموع دستورکارهای باز سیم به کابل'),
    ('تعداد دستورکارهای باز مربوط به تست 5', 'مجموع دستورکارهای باز نیرورسانی'),
    ('تعداد دستورکارهای باز مربوط به تست 6', 'مجموع دستورکارهای باز تلفات'),
    ('تعداد دستورکارهای باز مربوط به تست 7',  'مجموع دستورکارهای باز توسعه و احداث و اصلاح و روشنایی معابر و برگشتی و طرح جامع بم')]

# %%
for item in my_list2:
    new_t = test_ref(name = item[0] , test_num= item[0][-1:] , majmo_name= item[1] , additional={"soorat_vaziat_moshaver":"صورت وضعیت نزد مشاور"})
    session.add(new_t)
session.commit()

# %% [markdown]
# شهرها

# %%
citiesdf = dataframe[[('مدیریت برق شهرستان', ''),('کد امور', '')]][0:16]
citiesls = []
for i , row in citiesdf.iterrows():
    city = cities(
    name = row[('مدیریت برق شهرستان', '')],
    code_omor = row[('کد امور', '')]
    )
    citiesls.append(city)
session.add_all(citiesls)
session.commit()

# %% [markdown]
# تست ها

# %%
test1df = dataframe[[('مدیریت برق شهرستان', ''),
 ('سال', ''),
 ('ماه', '') , ('تعداد دستورکارهای باز مربوط به تست 1', 'دردست اجرا'),
 ('تعداد دستورکارهای باز مربوط به تست 1', 'تهیه صورت وضعیت'),
 ('تعداد دستورکارهای باز مربوط به تست 1', 'صورت وضعیت نزد ستاد'),
 ('تعداد دستورکارهای باز مربوط به تست 1', 'صورت وضعیت نزد مالی'),]]

# %%
test1ls = []
for i ,row in test1df.iterrows():
    ntest1 = tests(
        city_name = row[('مدیریت برق شهرستان', '')],
        test_num = 1,
        year = row[('سال', '')],
        month = row[('ماه', '')],
        dardast_ejra = row[('تعداد دستورکارهای باز مربوط به تست 1', 'دردست اجرا')],
        tahie_soorat_vaziat = row[('تعداد دستورکارهای باز مربوط به تست 1', 'تهیه صورت وضعیت')],
        soorat_vaziat_setad = row[('تعداد دستورکارهای باز مربوط به تست 1', 'صورت وضعیت نزد ستاد')],
        soorat_vaziat_mali = row[('تعداد دستورکارهای باز مربوط به تست 1', 'صورت وضعیت نزد مالی')],
        additional=None
    )
    test1ls.append(ntest1)
session.add_all(test1ls)
session.commit()
# Out:
# 2025-07-18 02:13:03,970 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-18 02:13:03,980 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:03,983 INFO sqlalchemy.engine.Engine [generated in 0.00236s] (1,)
# 2025-07-18 02:13:03,988 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:03,992 INFO sqlalchemy.engine.Engine [cached since 0.01055s ago] (1,)
# 2025-07-18 02:13:04,000 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# ...

# %%
test2df = dataframe[[('مدیریت برق شهرستان', ''),
 ('سال', ''),
 ('ماه', '') , ('تعداد دستورکارهای باز مربوط به تست 2', 'دردست اجرا'),
 ('تعداد دستورکارهای باز مربوط به تست 2', 'تهیه صورت وضعیت'),
 ('تعداد دستورکارهای باز مربوط به تست 2', 'صورت وضعیت نزد ستاد'),
 ('تعداد دستورکارهای باز مربوط به تست 2', 'صورت وضعیت نزد مالی'),]]

# %%
test2ls = []
for i ,row in test2df.iterrows():
    ntest2 = tests(
        city_name = row[('مدیریت برق شهرستان', '')],
        test_num=2,
        year = row[('سال', '')],
        month = row[('ماه', '')],
        dardast_ejra = row[('تعداد دستورکارهای باز مربوط به تست 2', 'دردست اجرا')],
        tahie_soorat_vaziat = row[('تعداد دستورکارهای باز مربوط به تست 2', 'تهیه صورت وضعیت')],
        soorat_vaziat_setad = row[('تعداد دستورکارهای باز مربوط به تست 2', 'صورت وضعیت نزد ستاد')],
        soorat_vaziat_mali = row[('تعداد دستورکارهای باز مربوط به تست 2', 'صورت وضعیت نزد مالی')],
        additional=None
    )
    test2ls.append(ntest2)
session.add_all(test2ls)
session.commit()
# Out:
# 2025-07-18 02:13:04,443 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:04,445 INFO sqlalchemy.engine.Engine [cached since 0.4639s ago] (2,)
# 2025-07-18 02:13:04,449 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:04,449 INFO sqlalchemy.engine.Engine [cached since 0.4703s ago] (2,)
# 2025-07-18 02:13:04,454 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:04,456 INFO sqlalchemy.engine.Engine [cached since 0.4763s ago] (2,)
# ...

# %%
test3df = dataframe[[('مدیریت برق شهرستان', ''),
 ('سال', ''),
 ('ماه', '') , ('تعداد دستورکارهای باز مربوط به تست 3', 'دردست اجرا'),
 ('تعداد دستورکارهای باز مربوط به تست 3', 'تهیه صورت وضعیت'),
 ('تعداد دستورکارهای باز مربوط به تست 3', 'صورت وضعیت نزد ستاد'),
 ('تعداد دستورکارهای باز مربوط به تست 3', 'صورت وضعیت نزد مالی'),]]

# %%
test3ls = []
for i ,row in test3df.iterrows():
    ntest3 = tests(
        city_name = row[('مدیریت برق شهرستان', '')],
        test_num=3,
        year = row[('سال', '')],
        month = row[('ماه', '')],
        dardast_ejra = row[('تعداد دستورکارهای باز مربوط به تست 3', 'دردست اجرا')],
        tahie_soorat_vaziat = row[('تعداد دستورکارهای باز مربوط به تست 3', 'تهیه صورت وضعیت')],
        soorat_vaziat_setad = row[('تعداد دستورکارهای باز مربوط به تست 3', 'صورت وضعیت نزد ستاد')],
        soorat_vaziat_mali = row[('تعداد دستورکارهای باز مربوط به تست 3', 'صورت وضعیت نزد مالی')],
        additional=None
    )
    test3ls.append(ntest3)
session.add_all(test3ls)
session.commit()
# Out:
# 2025-07-18 02:13:04,883 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:04,886 INFO sqlalchemy.engine.Engine [cached since 0.9049s ago] (3,)
# 2025-07-18 02:13:04,890 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:04,893 INFO sqlalchemy.engine.Engine [cached since 0.9143s ago] (3,)
# 2025-07-18 02:13:04,899 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:04,899 INFO sqlalchemy.engine.Engine [cached since 0.9207s ago] (3,)
# ...

# %%
test4df = dataframe[[('مدیریت برق شهرستان', ''),
 ('سال', ''),
 ('ماه', '') , ('تعداد دستورکارهای باز مربوط به تست 4', 'دردست اجرا'),
 ('تعداد دستورکارهای باز مربوط به تست 4', 'تهیه صورت وضعیت'),
 ('تعداد دستورکارهای باز مربوط به تست 4', 'صورت وضعیت نزد مشاور'),
 ('تعداد دستورکارهای باز مربوط به تست 4', 'صورت وضعیت نزد ستاد'),
 ('تعداد دستورکارهای باز مربوط به تست 4', 'صورت وضعیت نزد مالی'),]]

# %%
test4ls = []
for i ,row in test4df.iterrows():
    ntest4 = tests(
        city_name = row[('مدیریت برق شهرستان', '')],
        test_num=4,
        year = row[('سال', '')],
        month = row[('ماه', '')],
        dardast_ejra = row[('تعداد دستورکارهای باز مربوط به تست 4', 'دردست اجرا')],
        tahie_soorat_vaziat = row[('تعداد دستورکارهای باز مربوط به تست 4', 'تهیه صورت وضعیت')],
        soorat_vaziat_setad = row[('تعداد دستورکارهای باز مربوط به تست 4', 'صورت وضعیت نزد ستاد')],
        soorat_vaziat_mali = row[('تعداد دستورکارهای باز مربوط به تست 4', 'صورت وضعیت نزد مالی')],
        additional={'soorat_vaziat_moshaver' : row[('تعداد دستورکارهای باز مربوط به تست 4', 'صورت وضعیت نزد مشاور')]}

    )
    test4ls.append(ntest4)
session.add_all(test4ls)
session.commit()
# Out:
# 2025-07-18 02:13:05,463 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:05,468 INFO sqlalchemy.engine.Engine [cached since 1.487s ago] (4,)
# 2025-07-18 02:13:05,476 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:05,479 INFO sqlalchemy.engine.Engine [cached since 1.499s ago] (4,)
# 2025-07-18 02:13:05,484 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:05,484 INFO sqlalchemy.engine.Engine [cached since 1.505s ago] (4,)
# ...

# %%
session.rollback()

# %%
newt = tests(city_name = "شهر 1" , test_num=9 ,year = 1 ,month=1 , dardast_ejra=1,tahie_soorat_vaziat=2 , soorat_vaziat_setad=1 , soorat_vaziat_mali=0 , additional={"like_me" : 299})
session.add(newt)
session.commit()
# Out:
# 2025-07-18 02:13:36,728 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:36,729 INFO sqlalchemy.engine.Engine [cached since 32.75s ago] (9,)

# %%
q = test_ref(name= "test22" , test_num= 9 , majmo_name= " leo" , additional={"like_me" : "میو"})
session.add(q)
session.commit()

# %%
test5df = dataframe[[('مدیریت برق شهرستان', ''),
 ('سال', ''),
 ('ماه', '') , ('تعداد دستورکارهای باز مربوط به تست 5', 'دردست اجرا'),
 ('تعداد دستورکارهای باز مربوط به تست 5', 'تهیه صورت وضعیت'),
 ('تعداد دستورکارهای باز مربوط به تست 5', 'صورت وضعیت نزد مشاور'),
 ('تعداد دستورکارهای باز مربوط به تست 5', 'صورت وضعیت نزد ستاد'),
 ('تعداد دستورکارهای باز مربوط به تست 5', 'صورت وضعیت نزد مالی'),]]

# %%
test5ls = []
for i ,row in test5df.iterrows():
    ntest5 = tests(
        city_name = row[('مدیریت برق شهرستان', '')],
        test_num=5,
        year = row[('سال', '')],
        month = row[('ماه', '')],
        dardast_ejra = row[('تعداد دستورکارهای باز مربوط به تست 5', 'دردست اجرا')],
        tahie_soorat_vaziat = row[('تعداد دستورکارهای باز مربوط به تست 5', 'تهیه صورت وضعیت')],
        soorat_vaziat_setad = row[('تعداد دستورکارهای باز مربوط به تست 5', 'صورت وضعیت نزد ستاد')],
        soorat_vaziat_mali = row[('تعداد دستورکارهای باز مربوط به تست 5', 'صورت وضعیت نزد مالی')] ,
        additional={"soorat_vaziat_moshaver" : row[('تعداد دستورکارهای باز مربوط به تست 5', 'صورت وضعیت نزد مشاور')]}
    )
    test5ls.append(ntest5)
session.add_all(test5ls)
session.commit()
# Out:
# 2025-07-18 02:13:47,102 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:47,102 INFO sqlalchemy.engine.Engine [cached since 43.12s ago] (5,)
# 2025-07-18 02:13:47,107 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:47,109 INFO sqlalchemy.engine.Engine [cached since 43.13s ago] (5,)
# 2025-07-18 02:13:47,109 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:47,109 INFO sqlalchemy.engine.Engine [cached since 43.13s ago] (5,)
# ...

# %%
test6df = dataframe[[('مدیریت برق شهرستان', ''),
 ('سال', ''),
 ('ماه', '') , ('تعداد دستورکارهای باز مربوط به تست 6', 'دردست اجرا'),
 ('تعداد دستورکارهای باز مربوط به تست 6', 'تهیه صورت وضعیت'),
 ('تعداد دستورکارهای باز مربوط به تست 6', 'صورت وضعیت نزد مشاور'),
 ('تعداد دستورکارهای باز مربوط به تست 6', 'صورت وضعیت نزد ستاد'),
 ('تعداد دستورکارهای باز مربوط به تست 6', 'صورت وضعیت نزد مالی'),]]

# %%
test6ls = []
for i ,row in test6df.iterrows():
    ntest6 = tests(
        city_name = row[('مدیریت برق شهرستان', '')],
        test_num=6,
        year = row[('سال', '')],
        month = row[('ماه', '')],
        dardast_ejra = row[('تعداد دستورکارهای باز مربوط به تست 6', 'دردست اجرا')],
        tahie_soorat_vaziat = row[('تعداد دستورکارهای باز مربوط به تست 6', 'تهیه صورت وضعیت')],
        soorat_vaziat_setad = row[('تعداد دستورکارهای باز مربوط به تست 6', 'صورت وضعیت نزد ستاد')],
        soorat_vaziat_mali = row[('تعداد دستورکارهای باز مربوط به تست 6', 'صورت وضعیت نزد مالی')],
        additional={"soorat_vaziat_moshaver" : row[('تعداد دستورکارهای باز مربوط به تست 6', 'صورت وضعیت نزد مشاور')]}
    )
    test6ls.append(ntest6)
session.add_all(test6ls)
session.commit()
# Out:
# 2025-07-18 02:13:49,499 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:49,500 INFO sqlalchemy.engine.Engine [cached since 45.52s ago] (6,)
# 2025-07-18 02:13:49,505 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:49,506 INFO sqlalchemy.engine.Engine [cached since 45.53s ago] (6,)
# 2025-07-18 02:13:49,511 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:49,511 INFO sqlalchemy.engine.Engine [cached since 45.53s ago] (6,)
# ...

# %%
test7df = dataframe[[('مدیریت برق شهرستان', ''),
 ('سال', ''),
 ('ماه', '') , ('تعداد دستورکارهای باز مربوط به تست 7', 'دردست اجرا'),
 ('تعداد دستورکارهای باز مربوط به تست 7', 'تهیه صورت وضعیت'),
 ('تعداد دستورکارهای باز مربوط به تست 7', 'صورت وضعیت نزد مشاور'),
 ('تعداد دستورکارهای باز مربوط به تست 7', 'صورت وضعیت نزد ستاد'),
 ('تعداد دستورکارهای باز مربوط به تست 7', 'صورت وضعیت نزد مالی'),]]

# %%
test7ls = []
for i ,row in test7df.iterrows():
    ntest7 = tests(
        city_name = row[('مدیریت برق شهرستان', '')],
        test_num= 7,
        year = row[('سال', '')],
        month = row[('ماه', '')],
        dardast_ejra = row[('تعداد دستورکارهای باز مربوط به تست 7', 'دردست اجرا')],
        tahie_soorat_vaziat = row[('تعداد دستورکارهای باز مربوط به تست 7', 'تهیه صورت وضعیت')],
        soorat_vaziat_setad = row[('تعداد دستورکارهای باز مربوط به تست 7', 'صورت وضعیت نزد ستاد')],
        soorat_vaziat_mali = row[('تعداد دستورکارهای باز مربوط به تست 7', 'صورت وضعیت نزد مالی')],
        additional={"soorat_vaziat_moshaver" : row[('تعداد دستورکارهای باز مربوط به تست 7', 'صورت وضعیت نزد مشاور')]}
    )
    test7ls.append(ntest7)
session.add_all(test7ls)
session.commit()
# Out:
# 2025-07-18 02:13:51,256 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:51,258 INFO sqlalchemy.engine.Engine [cached since 47.28s ago] (7,)
# 2025-07-18 02:13:51,264 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:51,264 INFO sqlalchemy.engine.Engine [cached since 47.28s ago] (7,)
# 2025-07-18 02:13:51,268 INFO sqlalchemy.engine.Engine SELECT tests_refs.test_id, tests_refs.test_name, tests_refs.test_num, tests_refs.majmo_name, tests_refs.additional_attrs
# FROM tests_refs
# WHERE tests_refs.test_num = ?
# 2025-07-18 02:13:51,270 INFO sqlalchemy.engine.Engine [cached since 47.29s ago] (7,)
# ...
